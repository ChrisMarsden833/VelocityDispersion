# %% [markdown]
# # Velocity Dispersion Comparison with real data

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
deNicola = pd.read_csv("deNicolaData.csv", sep=',')

# %%
deNicola = deNicola[deNicola["stellar_mass"] != "null"]

# %%
deNicola
# Out:
#         Name Morphology  A  Distance_Mpc  Distance_Error_Mpc  \
# 4     NGC821         S0  1         23.40                1.80
# 5    NGC1023        SB0  2         10.81                0.80
# 9    NGC3115        S0/  2          9.54                0.40
# 12   NGC3377         E5  1         10.99                0.46
# 16   NGC3608         E1  0         22.80                1.50
# 23   NGC4459         E2  1         16.01                0.52
# 24   NGC4473         E5  1         15.25                0.49
# 25   NGC4564         S0  2         15.94                0.51
# 27   NGC4649         E2  0         16.46                0.61
# 28   NGC4697         E5  1         12.54                0.40
# 42   NGC1407         E0  0         28.00                3.40
# 54   NGC7457         S0  2         12.50                1.20
# 58  NGC4486A         E2  1         16.00                0.52
# 70   NGC4594         Sa  2          9.87                0.82
#
#     Black_Hole_Mass_Msun  Black_Hole_Mass_Error_Msun  velocity_dispersion_kms  \
# 4                   8.22                        0.21                    2.320
# 5                   7.62                        0.06                    2.310
# 9                   8.95                        0.10                    2.360
# 12                  8.25                        0.25                    2.160
# 16                  8.67                        0.10                    2.260
# 23                  7.84                        0.09                    2.220
# 24                  7.95                        0.24                    2.280
# 25                  7.95                        0.12                    2.210
# 27                  9.67                        0.10                    2.580
# 28                  8.13                        0.01                    2.250
# 42                  9.65                        0.08                    2.442
# 54                  6.95                        0.30                    1.830
# 58                  7.10                        0.15                    2.160
# 70                  8.82                        0.04                    2.380
#
#     velocity_dispersion_error_kms  Luminosity_Lsun  Luminosity_Error_Lsun  \
# 4                           0.020            10.84                   0.31
# 5                           0.020            10.45                   0.07
# 9                           0.020            10.93                   0.06
# 12                          0.020            10.64                   0.25
# 16                          0.020            11.04                   0.25
# 23                          0.020            10.64                   0.25
# 24                          0.020            10.80                   0.25
# 25                          0.020            10.15                   0.06
# 27                          0.020            11.66                   0.06
# 28                          0.020            11.17                   0.31
# 42                          0.003            11.72                   0.12
# 54                          0.020             9.69                   0.08
# 58                          0.010            10.08                   0.05
# 70                          0.020            10.79                   0.25
#
#     Radius_kpc  Radius_error_kpc  B stellar_mass Sersic_Index
# 4         0.33              0.03  1           11            6
# 5        -0.41              0.03  1        10.99          4.2
# 9         0.20              0.06  1        10.93          4.7
# 12        0.52              0.02  1         10.5          5.9
# 16        0.68              0.03  1        11.03          5.3
# 23        0.00              0.01  1        10.98          5.4
# 24        0.44              0.01  1        10.96            5
# 25       -0.41              0.01  1        10.58          3.2
# 27        0.90              0.02  0         11.6          4.6
# 28        0.64              0.01  1        11.15          5.3
# 42        0.97              0.05  0         11.6          4.9
# 54       -0.28              0.04  1        10.13          2.6
# 58       -0.19              0.01  0        11.62          5.1
# 70       -0.03              0.08  1        11.41          3.2
